# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar el dataset

# %%
train_images = np.load('./train_data/kmnist-train-imgs.npz')['arr_0']
test_images = np.load('./test_data/kmnist-test-imgs.npz')['arr_0']
train_labels = np.load('./train_data/kmnist-train-labels.npz')['arr_0']
test_labels = np.load('./test_data/kmnist-test-labels.npz')['arr_0']

# %%
characters = pd.read_csv('./kmnist_classmap.csv', encoding = 'utf-8')

# %%
characters
# Out:
#    index codepoint char
# 0      0    U+304A    お
# 1      1    U+304D    き
# 2      2    U+3059    す
# 3      3    U+3064    つ
# 4      4    U+306A    な
# 5      5    U+306F    は
# 6      6    U+307E    ま
# 7      7    U+3084    や
# 8      8    U+308C    れ
# 9      9    U+3092    を

# %% [markdown]
# ## Visualizar algunas imágenes

# %%
plt.figure(figsize=(18, 16))
for i in range(20):
    plt.subplot(4, 5, i+1).set_title('Id: {}'.format(train_labels[i]))
    plt.imshow(train_images[i])
    plt.grid(False)
plt.show()
